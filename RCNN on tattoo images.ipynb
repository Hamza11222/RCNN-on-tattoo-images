# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
cwd_path = os.getcwd()
print(cwd_path)
data_path =cwd_path + '/gdrive/My Drive/images'
data_path
# Out:
# /content
# '/content/gdrive/My Drive/images'

# %%
files = os.listdir(data_path)
size = len(files)
print("Total samples:",size)
print(files[0])
# Out:
# Total samples: 890
# 1009019541_ad75c5b35f.PNG

# %%
data_path1 =cwd_path + '/gdrive/My Drive/annotation'
data_path1
files1 = os.listdir(data_path1)
size = len(files)
print("Total samples:",size)
print(files1[0])
# Out:
# Total samples: 890
# 1009019541_ad75c5b35f.txt

# %%
import cv2
from skimage.transform import resize
from skimage.io import imread
from skimage.color import rgb2gray
images = []
names = []
print(data_path)
for name in files:
    print(name) 
    img = imread(data_path + '/'+ name)
    grayscale = rgb2gray(img)
    resized_img = resize(grayscale, (416, 416,3))
    #image = cv2.resize(image,dsize=(64,64))
    #image = image.reshape((image.shape[0],image.shape[1],1))
    #print(resized_img)
    fname = name.split(".")[0]
    names .append(fname)
    images.append(resized_img)
    # split_var = file.split('_')
# Out:
# /content/gdrive/My Drive/images
# 1009019541_ad75c5b35f.PNG
# 1011255694_9062554e64.PNG
# 1024011331_d4d147e3bb.PNG
# 1046908494_dba8abe16a.PNG
# 105674462_58c7e87d39.PNG
# 1089200564_b048a0f43a.PNG
# 1093885445_4962fc3fe4.PNG
# 1094192991_a46ca53e50.PNG
# 1094201835_e77ae97d80.PNG
# 1094262579_2632d6d8c2.PNG
# 1094282721_139792966c.PNG
# 1094952484_c9260976a7.PNG
# 1095018976_844da9c8ff.PNG
# 1095020932_ae2f343883.PNG
# 1095024602_20919049ac.PNG
# 10971006892551804891.PNG
# 1101137366_8926b4ab79.PNG
# 1108566904_6384a3bad5.PNG
# 117120812_2b30638a7b.PNG
# 1185523215_80ca94ea21.PNG
# 1197720849_adc3d46046.PNG
# 120852263_60faacb01e.PNG
# 1219663380_f0e2d08238.PNG
# 122144380_e11e7bd9af.PNG
# 1225224232_c2388c99a7.PNG
# 1227427019_adb2dcd507.PNG
# 1229369901_8ef5d43dcf.PNG
# 123646178_909a0c8cec.PNG
# 125353686_f2d1ef48da.PNG
# 1254149851_22924a919f.PNG
# 1268964755_c2b24e007a.PNG
# 127661510_dfbdf75ee8.PNG
# 12778417_289408de33.PNG
# 1286505016_9bf7419ea1.PNG
# ...

# %%
images[5].shape
# Out:
# (416, 416, 3)

# %%
import cv2
from skimage.transform import resize
from skimage.io import imread
from skimage.color import rgb2gray
print(data_path1)
for filename in os.listdir(data_path1):
    # print(filename)
    f = open(data_path1+'/'+filename,"r")
    fileline=f.readline()
    split_var = fileline.split(' ')
    print(split_var)
# Out:
# /content/gdrive/My Drive/annotation
# ['0', '177', '158', '74', '48']
# ['1', '104', '40', '238', '376']
# ['0', '0', '250', '411', '162']
# ['0', '105', '49', '182', '327']
# ['2', '108', '0', '177', '379']
# ['3', '177', '101', '112', '91']
# ['1', '39', '69', '301', '307']
# ['1', '0', '14', '376', '382']
# ['1', '12', '64', '377', '322']
# ['1', '110', '73', '205', '280']
# ['3', '0', '92', '368', '231']
# ['1', '29', '26', '367', '365']
# ['1', '61', '0', '355', '416']
# ['1', '63', '120', '278', '226']
# ['1', '65', '23', '299', '368']
# ['0', '211', '110', '43', '200']
# ['0', '94', '165', '297', '211']
# ['2', '118', '169', '137', '149']
# ['1', '159', '142', '145', '153']
# ['0', '153', '122', '102', '162']
# ['0', '106', '-1', '203', '300']
# ['0', '168', '90', '62', '91']
# ['1', '218', '227', '141', '161']
# ['2', '114', '163', '155', '63']
# ['0', '199', '183', '38', '201']
# ['0', '0', '101', '354', '312']
# ['0', '232', '232', '50', '70']
# ...

# %%
import matplotlib 
import matplotlib.pyplot as plt
a=names[18] + ".txt"
a
_, axis = plt.subplots(1, figsize=(12, 8))
sample = images[18]
imout = sample.copy()
axis.imshow(sample[:,:,0])
for filename in os.listdir(data_path1):
  if a==filename:
    print(filename)
    f = open(data_path1+'/'+filename,"r")
    fileline=f.readline()
    split_var = fileline.split(' ')
    print(split_var[1])
    xy = [
            int(split_var[1]),
            int(split_var[2])
        ];
    x =int(split_var[1])
    y =int(split_var[2])          
    w = int(split_var[3])
    h = int(split_var[4])
    rectangle = matplotlib.patches.Rectangle(xy, w, h, 
                                                 edgecolor=plt.cm.RdBu(255,255,0), 
                                                 facecolor="none")
    timage = imout[y:y+h,x:x+w]
    print(timage)
    resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
    # train_images.append(resized)
    axis.add_patch(rectangle)
matplotlib.pyplot.show()
# Out:
# 117120812_2b30638a7b.txt
# 159
# [[[0.24649333 0.24649333 0.24649333]
#   [0.25264706 0.25264706 0.25264706]
#   [0.26301294 0.26301294 0.26301294]
#   ...
#   [0.28961569 0.28961569 0.28961569]
#   [0.25769255 0.25769255 0.25769255]
#   [0.19159137 0.19159137 0.19159137]]
#
#  [[0.21987569 0.21987569 0.21987569]
#   [0.2551698  0.2551698  0.2551698 ]
#   [0.27085608 0.27085608 0.27085608]
#   ...
#   [0.29410275 0.29410275 0.29410275]
#   [0.27029059 0.27029059 0.27029059]
#   [0.17982667 0.17982667 0.17982667]]
#
#  [[0.25124824 0.25124824 0.25124824]
#   [0.25909137 0.25909137 0.25909137]
#   [0.26301294 0.26301294 0.26301294]
#   ...
#   [0.30950627 0.30950627 0.30950627]
#   [0.26693451 0.26693451 0.26693451]
#   [0.21512078 0.21512078 0.21512078]]
#
#  ...
#
#  [[0.07002275 0.07002275 0.07002275]
#   [0.06217961 0.06217961 0.06217961]
#   [0.05882353 0.05882353 0.05882353]
#   ...
#   [0.58793765 0.58793765 0.58793765]
#   [0.59157647 0.59157647 0.59157647]
# ...

# %%
_, axis = plt.subplots(1, figsize=(12, 8))
axis.imshow(resized[:,:])

# %%
train_images=[]
train_labels=[]

# %%
import matplotlib 
import matplotlib.pyplot as plt
import cv2

for i,filename in enumerate(os.listdir(data_path1)):
    image = images[i]
    imout = image.copy() 
    print(filename)
    f = open(data_path1+'/'+filename,"r")
    fileline=f.readline()
    split_var = fileline.split(' ')
    print(split_var[1])
    xy = [
            int(split_var[1]),
            int(split_var[2])
        ];
    x =int(split_var[1])
    y =int(split_var[2])          
    w = int(split_var[3])
    h = int(split_var[4])
    print(x,y,w,h)
    timage = imout[y:y+h,x:x+w]
    #print(timage)
    try:
      resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
      train_images.append(resized)
      train_labels.append(split_var[0])
    except:  
      image = cv2.resize(image, (224,224), interpolation = cv2.INTER_AREA)
      train_images.append(image)
      train_labels.append(split_var[0])
# Out:
# 1009019541_ad75c5b35f.txt
# 177
# 177 158 74 48
# 1011255694_9062554e64.txt
# 104
# 104 40 238 376
# 1024011331_d4d147e3bb.txt
# 0
# 0 250 411 162
# 1046908494_dba8abe16a.txt
# 105
# 105 49 182 327
# 105674462_58c7e87d39.txt
# 108
# 108 0 177 379
# 1089200564_b048a0f43a.txt
# 177
# 177 101 112 91
# 1093885445_4962fc3fe4.txt
# 39
# 39 69 301 307
# 1094192991_a46ca53e50.txt
# 0
# 0 14 376 382
# 1094201835_e77ae97d80.txt
# 12
# 12 64 377 322
# 1094262579_2632d6d8c2.txt
# 110
# 110 73 205 280
# 1094282721_139792966c.txt
# 0
# 0 92 368 231
# 1095018976_844da9c8ff.txt
# 29
# 29 26 367 365
# 1094952484_c9260976a7.txt
# 61
# 61 0 355 416
# 1095020932_ae2f343883.txt
# 63
# 63 120 278 226
# 1095024602_20919049ac.txt
# 65
# 65 23 299 368
# 10971006892551804891.txt
# 211
# 211 110 43 200
# 1101137366_8926b4ab79.txt
# 94
# 94 165 297 211
# 1108566904_6384a3bad5.txt
# 118
# 118 169 137 149
# 117120812_2b30638a7b.txt
# 159
# 159 142 145 153
# 1197720849_adc3d46046.txt
# 153
# 153 122 102 162
# ...

# %%
a=train_images[90]
_, axis = plt.subplots(1, figsize=(12, 8))
axis.imshow(a[:,:])
print(train_labels[90])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1

# %%
train_images[3].shape
# Out:
# (224, 224, 3)

# %%
# import matplotlib 
# import matplotlib.pyplot as plt
# label=[]
# for filename in os.listdir(data_path1):
#     f = open(data_path1+'/'+filename,"r")
#     fileline=f.readline()
#     split_var = fileline.split(' ')
#     label.append(split_var[0])

# %%
# label

# %%
# import matplotlib.pyplot as plt
# def display(img):
#     plt.imshow(img[:,:,0])
#     plt.set_cmap('gray')
#     plt.show()
# idx = 60
# sample = images[idx]
# sample.shape
# display(sample)

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16

# %%
vggmodel = VGG16(weights='imagenet', include_top=True)
vggmodel.summary()
# Out:
# ...
# 553476096/553467096 [==============================] - 4s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
for layers in (vggmodel.layers)[:15]:
    #print(layers)
    layers.trainable = False

X= vggmodel.layers[-2].output

predictions = Dense(4, activation="softmax")(X)

model_final = Model(inputs = vggmodel.input, outputs = predictions)


opt = Adam(lr=0.01)

model_final.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics=["accuracy"])

model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
import numpy as np
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(np.array(train_labels))

del train_labels

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(train_images),Y,test_size=0.10)
#print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train[0:5000], y=y_train[0:5000])

tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("R-CNN.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=1, mode='auto')

# %%
hist = model_final.fit_generator(generator= traindata, steps_per_epoch= 20, epochs= 100, validation_data= testdata,callbacks=[checkpoint, early])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Epoch 1/100
# 20/20 [==============================] - ETA: 0s - loss: 1505301.3750 - accuracy: 0.3432
# Epoch 00001: val_loss improved from inf to 23235.93750, saving model to R-CNN.h5
# 20/20 [==============================] - 518s 27s/step - loss: 1505301.3750 - accuracy: 0.3432 - val_loss: 23235.9375 - val_accuracy: 0.1348
# Epoch 2/100
# 20/20 [==============================] - ETA: 0s - loss: 5521.8379 - accuracy: 0.2857
# Epoch 00002: val_loss improved from 23235.93750 to 441.97214, saving model to R-CNN.h5
# 20/20 [==============================] - 492s 25s/step - loss: 5521.8379 - accuracy: 0.2857 - val_loss: 441.9721 - val_accuracy: 0.1573
# Epoch 3/100
# ...

# %%
from tensorflow import keras
model = keras.models.load_model('/content/gdrive/My Drive/R-CNN.h5')

# %%
loss, acc = model.evaluate(testdata, verbose=2)
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# 3/3 - 43s - loss: 1.1439 - accuracy: 0.5730 - 43s/epoch - 14s/step
# Restored model, accuracy: 57.30%
